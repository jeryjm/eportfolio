# %% [markdown]
# <a href="https://colab.research.google.com/github/jeryjm/eportfolio/blob/master/LCS_Python_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Print my name

# %%
print("Stelios") # This is a text  " "
# Out:
# Stelios

# %%
# Print an integer

print(10)
# Out:
# 10

# %%
print(4.5)
# Out:
# 4.5

# %%
x = 10

print(x)
# Out:
# 10

# %%
name = "Stelios"
print(name)
# Out:
# Stelios

# %%
x = 10
y = 20
result = x+y

print(result)
# Out:
# 30

# %%
name = input("What is your name?")

print("Your name is: ", name)
# Out:
# What is your name?Stelios
# Your name is:  Stelios

# %%
age = input("How old are you?")
print(age)
# Out:
# How old are you?45
# 45

# %%
x = input("Give me a number: ")
y = input("Give me another number: ")

print(x+y) # Input by the user is alwas
# Out:
# Give me a number: 10
# Give me another number: 20
# 1020
